# %%
from bmiInput import bmiInput 
from bmiText import bmiText 
from bmicharts import bmicharts

# %%
#dodaj pomiar z konsoli
bmiInput()

# %%
#dodaj pomiary z pliku (pomiary muszą być w tym samym systemie)
bmiText()

# %%
#wygeneruj wykres
bmicharts()
# Out:
#     system  waga  wzrost    bmi
# 691      M  55.0   2.050  13.09
# 215      M  55.0   2.050  13.09
# 167      M  55.0   2.050  13.09
# 55       M  55.0   2.050  13.09
# 371      M  55.0   2.050  13.09
# ..     ...   ...     ...    ...
# 615      I  54.0   1.375  27.89
# 479      I  54.0   1.375  27.89
# 207      I  54.0   1.375  27.89
# 411      I  54.0   1.375  27.89
# 139      I  54.0   1.375  27.89
#
# [748 rows x 4 columns]
